# %% [markdown]
# <a href="https://colab.research.google.com/github/Thiagoo-Franca/lsh/blob/main/lsh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
#variaveis globais

tabelaHashingBaldes = [[] for _ in range(101)]

vocabulario = {
    "aa": 0, "ab":1, "ac": 2, "ad": 3, "ae": 4, "af": 5,
    "ba": 6, "bb": 7, "bc": 8, "bd": 9, "be": 10, "bf": 11,
    "ca": 12, "cb": 13, "cc": 14, "cd": 15, "ce": 16, "cf": 17,
    "da": 18, "db": 19, "dc": 20, "dd": 21, "de": 22, "df": 23,
    "ea": 24, "eb": 25, "ec": 26, "ed": 27, "ee": 28, "ef": 29,
    "fa": 30, "fb": 31, "fc": 32, "fd": 33, "fe": 34, "ff": 35,
    }

n = len(vocabulario)

#Shingles

def shingles (palavra):
    return (palavra[i:i+2] for i in range(len(palavra) - 1))

#Calcula a similaridade de Jaccard entre duas palavras
def calcular_jaccard(palavra1, palavra2):
    shingles1 = set(shingles(palavra1))
    shingles2 = set(shingles(palavra2))

    intersecao = shingles1 & shingles2
    uniao = shingles1 | shingles2

    similaridade = len(intersecao) / len(uniao)
    return similaridade


# Função para comparar todas as palavras em um balde usando a similaridade de Jaccard
def comparar_balde_lsh(balde):
    n = len(balde)

    if n == 1:
        print("O balde contém apenas uma palavra!")
        return

    for i in range(n):
        for j in range(i + 1, n):
            palavra1 = balde[i]
            palavra2 = balde[j]
            similaridade = calcular_jaccard(palavra1, palavra2)
            print(f"Similaridade entre '{palavra1}' e '{palavra2}': {similaridade:.2f}")

#Funcao Principal
def lsh(palavra):

    shingles_lista = []
    shingles_lista.append(shingles(palavra)) #[aa, ab, ba, ac, ca, aa, ac, ca, aa]

    #minHashing
    hash_bitmap = [0] * (n)
    min_hash_bitmap = [0] * n
    assinatura = []

    for i in range(len(shingles_lista)):
        if (shingles_lista[i] in vocabulario):
            hash_bitmap[vocabulario[shingles_lista[i]]] = 1 #marcar na lista os shingles que estão presentes na palavra

    for k in range(len(hash_bitmap)):
        if hash_bitmap[k] == 1:
            min_hash_bitmap[(random.randint(0, 100)) * i % n] = 1 #gerar um valor aleatório para cada shingle presente na palavra

    menores = [float('inf')] * 30 #inicializa a lista de menores com infinito

    for i in range(len(min_hash_bitmap)):
        if min_hash_bitmap[i] == 1:
            hashes = [(random.randrange(0, 100) * i) % n for _ in range(30)] #Gera funções aleatórias para cada shingle

            for j in range(30):
                if hashes[j] < menores[j]: #se o valor gerado for menor que o valor atual, substitui
                    menores[j] = hashes[j]
    assinatura = menores

    #lsh

    bandas = []
    banda_size = 2  # Cada banda contém 2 valores da assinatura
    for i in range(0, len(assinatura), banda_size):
        bandas.append(assinatura[i:i + banda_size])

    hash_bandas = {(random.randint(0, 200)) % 101 for _ in range(len(bandas))}

    for hash_banda in hash_bandas:
        tabelaHashingBaldes[hash_banda].append(palavra)
    return

#testes
lsh("abaaacadda")
lsh("ababbcadda")
lsh("babacbbaab")
lsh("bcbcacbcbb")
lsh("accdbbcdbc")
lsh("ddeeffabba")
#
# Comparando palavras no balde 10:
# Similaridade entre 'babacbbaab' e 'abadaffeae': 0.15
#
# Comparando palavras no balde 11:
# Similaridade entre 'ababbcadda' e 'acacacacac': 0.11
#
# Comparando palavras no balde 12:
# Similaridade entre 'abaaacadda' e 'ababababab': 0.25
#
# Comparando palavras no balde 13:
# Similaridade entre 'babacbbaab' e 'acaddfdaca': 0.08
#
# Comparando palavras no balde 14:
# Similaridade entre 'ababbcadda' e 'aaaeaaaffa': 0.00
# Similaridade entre 'ababbcadda' e 'ffabacbcbc': 0.25
# Similaridade entre 'aaaeaaaffa' e 'ffabacbcbc': 0.18
#
# Comparando palavras no balde 16:
# O balde contém apenas uma palavra!
#
# Comparando palavras no balde 17:
# Similaridade entre 'abaaacadda' e 'ababbcadda': 0.60
# Similaridade entre 'abaaacadda' e 'abbcbacbbd': 0.25
# Similaridade entre 'ababbcadda' e 'abbcbacbbd': 0.36
#
# Comparando palavras no balde 18:
# O balde contém apenas uma palavra!
#
# Comparando palavras no balde 19:
# O balde contém apenas uma palavra!
#
# Comparando palavras no balde 20:
# Similaridade entre 'bcbcbcbcdc' e 'acacacacac': 0.00
# Similaridade entre 'bcbcbcbcdc' e 'abadaffeae': 0.00
# Similaridade entre 'acacacacac' e 'abadaffeae': 0.00
#
# Comparando palavras no balde 21:
# Similaridade entre 'babacbbaab' e 'accdbbcdbc': 0.20
# Similaridade entre 'babacbbaab' e 'ddeeffabba': 0.25
# Similaridade entre 'babacbbaab' e 'aaaeaaaffa': 0.09
# Similaridade entre 'babacbbaab' e 'acaddfdaca': 0.08
# Similaridade entre 'accdbbcdbc' e 'ddeeffabba': 0.07
# Similaridade entre 'accdbbcdbc' e 'aaaeaaaffa': 0.00
# Similaridade entre 'accdbbcdbc' e 'acaddfdaca': 0.08
# Similaridade entre 'ddeeffabba' e 'aaaeaaaffa': 0.15
# Similaridade entre 'ddeeffabba' e 'acaddfdaca': 0.07
# Similaridade entre 'aaaeaaaffa' e 'acaddfdaca': 0.00
#
# Comparando palavras no balde 22:
# Similaridade entre 'bcbcacbcbb' e 'bcbcbcbcdc': 0.29
# Similaridade entre 'bcbcacbcbb' e 'acacacacac': 0.40
# Similaridade entre 'bcbcbcbcdc' e 'acacacacac': 0.00
#
# Comparando palavras no balde 23:
# O balde contém apenas uma palavra!
#
# Comparando palavras no balde 24:
# O balde contém apenas uma palavra!
#
# Comparando palavras no balde 25:
# O balde contém apenas uma palavra!
#
# Comparando palavras no balde 26:
# Similaridade entre 'ababbcadda' e 'accdbbcdbc': 0.17
# Similaridade entre 'ababbcadda' e 'ffabacbcbc': 0.25
# Similaridade entre 'ababbcadda' e 'ababababab': 0.25
# Similaridade entre 'ababbcadda' e 'abbcbacbbd': 0.36
# Similaridade entre 'accdbbcdbc' e 'ffabacbcbc': 0.18
# Similaridade entre 'accdbbcdbc' e 'ababababab': 0.00
# Similaridade entre 'accdbbcdbc' e 'abbcbacbbd': 0.30
# Similaridade entre 'ffabacbcbc' e 'ababababab': 0.29
# Similaridade entre 'ffabacbcbc' e 'abbcbacbbd': 0.56
# Similaridade entre 'ababababab' e 'abbcbacbbd': 0.29
#
# Comparando palavras no balde 27:
# Similaridade entre 'ababbcadda' e 'acaddfdaca': 0.36
# Similaridade entre 'ababbcadda' e 'abadaffeae': 0.31
# Similaridade entre 'acaddfdaca' e 'abadaffeae': 0.14
#
# Comparando palavras no balde 28:
# Similaridade entre 'bcbcacbcbb' e 'ffabacbcbc': 0.33
#
# Comparando palavras no balde 29:
# Similaridade entre 'bcbcacbcbb' e 'aaaeaaaffa': 0.00
# Similaridade entre 'bcbcacbcbb' e 'ababababab': 0.00
# Similaridade entre 'bcbcacbcbb' e 'abadaffeae': 0.00
# Similaridade entre 'aaaeaaaffa' e 'ababababab': 0.00
# Similaridade entre 'aaaeaaaffa' e 'abadaffeae': 0.36
# Similaridade entre 'ababababab' e 'abadaffeae': 0.22
#
# Comparando palavras no balde 30:
# Similaridade entre 'bcbcacbcbb' e 'ddeeffabba': 0.08
#
# Comparando palavras no balde 31:
# Similaridade entre 'acacacacac' e 'ffabacbcbc': 0.12
# Similaridade entre 'acacacacac' e 'abbcbacbbd': 0.12
# Similaridade entre 'ffabacbcbc' e 'abbcbacbbd': 0.56
#
# Comparando palavras no balde 32:
# O balde contém apenas uma palavra!
#
# Comparando palavras no balde 33:
# Similaridade entre 'abaaacadda' e 'babacbbaab': 0.40
# Similaridade entre 'abaaacadda' e 'aaaeaaaffa': 0.08
# Similaridade entre 'abaaacadda' e 'abbadaccac': 0.60
# Similaridade entre 'babacbbaab' e 'aaaeaaaffa': 0.09
# Similaridade entre 'babacbbaab' e 'abbadaccac': 0.40
# Similaridade entre 'aaaeaaaffa' e 'abbadaccac': 0.00
#
# Comparando palavras no balde 34:
# Similaridade entre 'ddeeffabba' e 'bcbcbcbcdc': 0.00
# Similaridade entre 'ddeeffabba' e 'ababababab': 0.22
# Similaridade entre 'bcbcbcbcdc' e 'ababababab': 0.00
#
# Comparando palavras no balde 36:
# Similaridade entre 'ddeeffabba' e 'acacacacac': 0.00
# Similaridade entre 'ddeeffabba' e 'abbcbacbbd': 0.23
# Similaridade entre 'ddeeffabba' e 'abadaffeae': 0.20
# Similaridade entre 'acacacacac' e 'abbcbacbbd': 0.12
# Similaridade entre 'acacacacac' e 'abadaffeae': 0.00
# Similaridade entre 'abbcbacbbd' e 'abadaffeae': 0.14
#
# Comparando palavras no balde 37:
# Similaridade entre 'babacbbaab' e 'bcbcbcbcdc': 0.11
# Similaridade entre 'babacbbaab' e 'acaddfdaca': 0.08
# Similaridade entre 'babacbbaab' e 'ababababab': 0.33
# Similaridade entre 'bcbcbcbcdc' e 'acaddfdaca': 0.00
# Similaridade entre 'bcbcbcbcdc' e 'ababababab': 0.00
# Similaridade entre 'acaddfdaca' e 'ababababab': 0.00
#
# Comparando palavras no balde 38:
# Similaridade entre 'abbadaccac' e 'abadaffeae': 0.31
#
# Comparando palavras no balde 39:
# Similaridade entre 'aaaeaaaffa' e 'ffabacbcbc': 0.18
# Similaridade entre 'aaaeaaaffa' e 'abbcbacbbd': 0.00
# Similaridade entre 'ffabacbcbc' e 'abbcbacbbd': 0.56
#
# Comparando palavras no balde 40:
# O balde contém apenas uma palavra!
#
# Comparando palavras no balde 41:
# Similaridade entre 'accdbbcdbc' e 'ddeeffabba': 0.07
#
# Comparando palavras no balde 42:
# Similaridade entre 'ddeeffabba' e 'acacacacac': 0.00
#
# Comparando palavras no balde 43:
# Similaridade entre 'ababbcadda' e 'ddeeffabba': 0.31
# Similaridade entre 'ababbcadda' e 'acacacacac': 0.11
# Similaridade entre 'ddeeffabba' e 'acacacacac': 0.00
#
# Comparando palavras no balde 44:
# Similaridade entre 'babacbbaab' e 'accdbbcdbc': 0.20
# Similaridade entre 'babacbbaab' e 'ffabacbcbc': 0.44
# Similaridade entre 'babacbbaab' e 'abbadaccac': 0.40
# Similaridade entre 'accdbbcdbc' e 'ffabacbcbc': 0.18
# Similaridade entre 'accdbbcdbc' e 'abbadaccac': 0.27
# Similaridade entre 'ffabacbcbc' e 'abbadaccac': 0.25
#
# Comparando palavras no balde 45:
# Similaridade entre 'acaddfdaca' e 'ababababab': 0.00
#
# Comparando palavras no balde 46:
# O balde contém apenas uma palavra!
#
# Comparando palavras no balde 47:
# Similaridade entre 'ddeeffabba' e 'acaddfdaca': 0.07
# Similaridade entre 'ddeeffabba' e 'abbcbacbbd': 0.23
# Similaridade entre 'ddeeffabba' e 'abadaffeae': 0.20
# Similaridade entre 'acaddfdaca' e 'abbcbacbbd': 0.08
# Similaridade entre 'acaddfdaca' e 'abadaffeae': 0.14
# Similaridade entre 'abbcbacbbd' e 'abadaffeae': 0.14
#
# Comparando palavras no balde 48:
# O balde contém apenas uma palavra!
#
# Comparando palavras no balde 49:
# Similaridade entre 'abaaacadda' e 'bcbcbcbcdc': 0.00
# Similaridade entre 'abaaacadda' e 'acaddfdaca': 0.50
# Similaridade entre 'abaaacadda' e 'ababababab': 0.25
# Similaridade entre 'bcbcbcbcdc' e 'acaddfdaca': 0.00
# Similaridade entre 'bcbcbcbcdc' e 'ababababab': 0.00
# Similaridade entre 'acaddfdaca' e 'ababababab': 0.00
#
# Comparando palavras no balde 50:
# Similaridade entre 'bcbcacbcbb' e 'acacacacac': 0.40
#
# Comparando palavras no balde 51:
# Similaridade entre 'acaddfdaca' e 'ababababab': 0.00
#
# Comparando palavras no balde 52:
# O balde contém apenas uma palavra!
#
# Comparando palavras no balde 53:
# Similaridade entre 'bcbcacbcbb' e 'acaddfdaca': 0.20
# Similaridade entre 'bcbcacbcbb' e 'abbcbacbbd': 0.50
# Similaridade entre 'acaddfdaca' e 'abbcbacbbd': 0.08
#
# Comparando palavras no balde 54:
# Similaridade entre 'abaaacadda' e 'bcbcacbcbb': 0.18
# Similaridade entre 'abaaacadda' e 'accdbbcdbc': 0.08
# Similaridade entre 'abaaacadda' e 'abbcbacbbd': 0.25
# Similaridade entre 'bcbcacbcbb' e 'accdbbcdbc': 0.38
# Similaridade entre 'bcbcacbcbb' e 'abbcbacbbd': 0.50
# Similaridade entre 'accdbbcdbc' e 'abbcbacbbd': 0.30
#
# Comparando palavras no balde 55:
# Similaridade entre 'ffabacbcbc' e 'abadaffeae': 0.23
#
# Comparando palavras no balde 56:
# Similaridade entre 'aaaeaaaffa' e 'acaddfdaca': 0.00
#
# Comparando palavras no balde 57:
# Similaridade entre 'ababbcadda' e 'ddeeffabba': 0.31
# Similaridade entre 'ababbcadda' e 'abbadaccac': 0.60
# Similaridade entre 'ddeeffabba' e 'abbadaccac': 0.21
#
# Comparando palavras no balde 58:
# O balde contém apenas uma palavra!
#
# Comparando palavras no balde 59:
# Similaridade entre 'aaaeaaaffa' e 'abbadaccac': 0.00
# Similaridade entre 'aaaeaaaffa' e 'abbcbacbbd': 0.00
# Similaridade entre 'abbadaccac' e 'abbcbacbbd': 0.36
#
# Comparando palavras no balde 60:
# Similaridade entre 'accdbbcdbc' e 'abbcbacbbd': 0.30
#
# Comparando palavras no balde 61:
# Similaridade entre 'abaaacadda' e 'ddeeffabba': 0.21
#
# Comparando palavras no balde 62:
# Similaridade entre 'babacbbaab' e 'bcbcbcbcdc': 0.11
#
# Comparando palavras no balde 63:
# Similaridade entre 'abaaacadda' e 'babacbbaab': 0.40
# Similaridade entre 'abaaacadda' e 'bcbcbcbcdc': 0.00
# Similaridade entre 'abaaacadda' e 'acacacacac': 0.25
# Similaridade entre 'abaaacadda' e 'abadaffeae': 0.31
# Similaridade entre 'babacbbaab' e 'bcbcbcbcdc': 0.11
# Similaridade entre 'babacbbaab' e 'acacacacac': 0.14
# Similaridade entre 'babacbbaab' e 'abadaffeae': 0.15
# Similaridade entre 'bcbcbcbcdc' e 'acacacacac': 0.00
# Similaridade entre 'bcbcbcbcdc' e 'abadaffeae': 0.00
# Similaridade entre 'acacacacac' e 'abadaffeae': 0.00
#
# Comparando palavras no balde 65:
# Similaridade entre 'babacbbaab' e 'bcbcacbcbb': 0.38
# Similaridade entre 'babacbbaab' e 'ffabacbcbc': 0.44
# Similaridade entre 'babacbbaab' e 'abbcbacbbd': 0.62
# Similaridade entre 'bcbcacbcbb' e 'ffabacbcbc': 0.33
# Similaridade entre 'bcbcacbcbb' e 'abbcbacbbd': 0.50
# Similaridade entre 'ffabacbcbc' e 'abbcbacbbd': 0.56
#
# Comparando palavras no balde 67:
# Similaridade entre 'abbadaccac' e 'acaddfdaca': 0.36
#
# Comparando palavras no balde 68:
# O balde contém apenas uma palavra!
#
# Comparando palavras no balde 69:
# Similaridade entre 'bcbcacbcbb' e 'bcbcbcbcdc': 0.29
# Similaridade entre 'bcbcacbcbb' e 'aaaeaaaffa': 0.00
# Similaridade entre 'bcbcbcbcdc' e 'aaaeaaaffa': 0.00
#
# Comparando palavras no balde 70:
# Similaridade entre 'accdbbcdbc' e 'abbadaccac': 0.27
#
# Comparando palavras no balde 71:
# Similaridade entre 'ababbcadda' e 'ababababab': 0.25
#
# Comparando palavras no balde 72:
# Similaridade entre 'ababbcadda' e 'abbadaccac': 0.60
# Similaridade entre 'ababbcadda' e 'abadaffeae': 0.31
# Similaridade entre 'abbadaccac' e 'abadaffeae': 0.31
#
# Comparando palavras no balde 74:
# Similaridade entre 'abbadaccac' e 'abadaffeae': 0.31
#
# Comparando palavras no balde 75:
# O balde contém apenas uma palavra!
#
# Comparando palavras no balde 76:
# Similaridade entre 'abaaacadda' e 'ababbcadda': 0.60
# Similaridade entre 'abaaacadda' e 'accdbbcdbc': 0.08
# Similaridade entre 'abaaacadda' e 'ddeeffabba': 0.21
# Similaridade entre 'ababbcadda' e 'accdbbcdbc': 0.17
# Similaridade entre 'ababbcadda' e 'ddeeffabba': 0.31
# Similaridade entre 'accdbbcdbc' e 'ddeeffabba': 0.07
#
# Comparando palavras no balde 77:
# Similaridade entre 'bcbcbcbcdc' e 'abadaffeae': 0.00
#
# Comparando palavras no balde 78:
# Similaridade entre 'bcbcacbcbb' e 'ababababab': 0.00
#
# Comparando palavras no balde 79:
# Similaridade entre 'acacacacac' e 'abbadaccac': 0.25
#
# Comparando palavras no balde 80:
# Similaridade entre 'abaaacadda' e 'ababababab': 0.25
#
# Comparando palavras no balde 81:
# O balde contém apenas uma palavra!
#
# Comparando palavras no balde 82:
# Similaridade entre 'bcbcacbcbb' e 'ddeeffabba': 0.08
# Similaridade entre 'bcbcacbcbb' e 'bcbcbcbcdc': 0.29
# Similaridade entre 'ddeeffabba' e 'bcbcbcbcdc': 0.00
#
# Comparando palavras no balde 83:
# O balde contém apenas uma palavra!
#
# Comparando palavras no balde 84:
# Similaridade entre 'abaaacadda' e 'ffabacbcbc': 0.25
# Similaridade entre 'abaaacadda' e 'ababababab': 0.25
# Similaridade entre 'ffabacbcbc' e 'ababababab': 0.29
#
# Comparando palavras no balde 85:
# Similaridade entre 'bcbcbcbcdc' e 'ffabacbcbc': 0.22
#
# Comparando palavras no balde 88:
# O balde contém apenas uma palavra!
#
# Comparando palavras no balde 89:
# O balde contém apenas uma palavra!
#
# Comparando palavras no balde 90:
# O balde contém apenas uma palavra!
#
# Comparando palavras no balde 91:
# Similaridade entre 'abaaacadda' e 'ababbcadda': 0.60
# Similaridade entre 'abaaacadda' e 'bcbcacbcbb': 0.18
# Similaridade entre 'abaaacadda' e 'aaaeaaaffa': 0.08
# Similaridade entre 'ababbcadda' e 'bcbcacbcbb': 0.30
# Similaridade entre 'ababbcadda' e 'aaaeaaaffa': 0.00
# Similaridade entre 'bcbcacbcbb' e 'aaaeaaaffa': 0.00
#
# Comparando palavras no balde 92:
# Similaridade entre 'babacbbaab' e 'bcbcacbcbb': 0.38
# Similaridade entre 'babacbbaab' e 'ddeeffabba': 0.25
# Similaridade entre 'babacbbaab' e 'acacacacac': 0.14
# Similaridade entre 'babacbbaab' e 'abbadaccac': 0.40
# Similaridade entre 'bcbcacbcbb' e 'ddeeffabba': 0.08
# Similaridade entre 'bcbcacbcbb' e 'acacacacac': 0.40
# Similaridade entre 'bcbcacbcbb' e 'abbadaccac': 0.30
# Similaridade entre 'ddeeffabba' e 'acacacacac': 0.00
# Similaridade entre 'ddeeffabba' e 'abbadaccac': 0.21
# Similaridade entre 'acacacacac' e 'abbadaccac': 0.25
#
# Comparando palavras no balde 94:
# Similaridade entre 'ffabacbcbc' e 'abbadaccac': 0.25
# Similaridade entre 'ffabacbcbc' e 'ababababab': 0.29
# Similaridade entre 'abbadaccac' e 'ababababab': 0.25
#
# Comparando palavras no balde 95:
# Similaridade entre 'ababbcadda' e 'bcbcbcbcdc': 0.09
# Similaridade entre 'ababbcadda' e 'ababababab': 0.25
# Similaridade entre 'bcbcbcbcdc' e 'ababababab': 0.00
#
# Comparando palavras no balde 96:
# Similaridade entre 'abbadaccac' e 'abadaffeae': 0.31
#
# Comparando palavras no balde 97:
# O balde contém apenas uma palavra!
#
# Comparando palavras no balde 98:
# O balde contém apenas uma palavra!
#
# Comparando palavras no balde 99:
# Similaridade entre 'bcbcbcbcdc' e 'acacacacac': 0.00
